# %%
cd /Users/jmcarp/code/neurotrends
# Out:
# /Users/jmcarp/code/neurotrends

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import collections

from neurotrends.model import mongo
from neurotrends.model.article import Article
from neurotrends.analysis import mapreduce
from modularodm.query.querydialect import DefaultQueryDialect as Q
from neurotrends import pattern

# %%
Article.find(Q('tags', 'eq', [])).count()
# Out:
# 2273

# %%
# Tag missing articles, catching exceptions

for article in Article.find(Q('tags', 'eq', [])):
    try:
        article.tag()
    except Exception as error:
        print 'Error on article {}: {}'.format(
            article.pmid,
            error
        )
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will not be corrected. [pdf.py:1130]
# UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal [dammit.py:269]
# Error on article 17208459: Command '['gs', '-dBATCH', '-dNOPAUSE', '-sDEVICE=tiffg4', '-r300', '-sOutputFile=/Users/jmcarp/Desktop/neurotrends-test/pdf/17208459-page-%03d.tif', u'/Users/jmcarp/Desktop/neurotrends-test/pdf/17208459.pdf']' returned non-zero exit status 1
# UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal [dammit.py:273]
# UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal [dammit.py:277]
# UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal [dammit.py:280]
# UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal [dammit.py:283]

# %%
# %%time
mongo.article.map_reduce(mapreduce.map_func, mapreduce.reduce_func, 'mr')
mongo.article.map_reduce(mapreduce.map_func_year, mapreduce.reduce_func, 'mr_year')
mongo.article.map_reduce(mapreduce.map_func_version, mapreduce.reduce_func, 'mr_version')
mongo.article.map_reduce(mapreduce.map_func_version_year, mapreduce.reduce_func, 'mr_version_year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-03312f84ceae> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"mongo.article.map_reduce(mapreduce.map_func, mapreduce.reduce_func, 'mr')\nmongo.article.map_reduce(mapreduce.map_func_year, mapreduce.reduce_func, 'mr_year')\nmongo.article.map_reduce(mapreduce.map_func_version, mapreduce.reduce_func, 'mr_version')\nmongo.article.map_reduce(mapreduce.map_func_version_year, mapreduce.reduce_func, 'mr_version_year')")
#
# /Users/jmcarp/env/neurotrends/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2127             magic_arg_s = self.var_expand(line, stack_depth)
#    2128             with self.builtin_trap:
# -> 2129                 result = fn(magic_arg_s, cell)
#    2130             return result
#    2131
#
# /Users/jmcarp/env/neurotrends/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /Users/jmcarp/env/neurotrends/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     189     # but it's overkill for just that one bit of state.
#     190     def magic_deco(arg):
# --> 191         call = lambda f, *a, **k: f(*a, **k)
#     192
#     193         if callable(arg):
#
# /Users/jmcarp/env/neurotrends/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1043         else:
#    1044             st = clock2()
# -> 1045             exec code in glob, local_ns
#    1046             end = clock2()
#    1047             out = None
#
# <timed exec> in <module>()
#
# AttributeError: 'module' object has no attribute 'map_func_year'

# %%
# %%time

mongo.article.map_reduce(mapreduce.map_func, mapreduce.reduce_func, 'mr_all')
# Out:
# CPU times: user 725 µs, sys: 147 µs, total: 872 µs
# Wall time: 4.98 s
# Collection(Database(MongoClient('localhost', 27017), u'neurotrends'), u'mr_all')

# %%
mongo.article.find_one({'_id': '526735f576eebde4999f5117'})['tags']
# Out:
# [{u'category': u'analysis',
#   u'context': u'er of presentation was randomized. We utilized an event-related design for the repetition priming paradigm, because it i',
#   u'label': u'event'},
#  {u'category': u'analysis',
#   u'context': u'ng paradigm, because it is more powerful than the block design for examining activation in response to single, s',
#   u'label': u'block'},
#  {u'category': u'tool',
#   u'context': u"stered first to that participant's anatomical (T1; mprage) scans, and then registered to standard space usin",
#   u'label': u'mprage'},
#  {u'category': u'analysis',
#   u'context': u', we further included, in this study, insula as a region of interest and tentatively hypothesized repetition priming e',
#   u'label': u'roi'},
#  {u'category': u'tool',
#   u'context': u"FMRI Expert Analysis) Tool, Version 5.90, part of FSL (FMRIB's Software Library, www.fmrib.ox.ac.uk/fsl",
#   u'label': u'fsl',
#   u'version': u'?'},
#  {u'category': u'tool',
#   u'context': u'nsistency. Perhaps more importantly, the large RT variances in priming effects for the emotional and neutr',
#   u'label': u'varian'},
#  {u'category': u'analysis',
#   u'context': u'ary, www.fmrib.ox.ac.uk/fsl). The BOLD scans were motion corrected and spatial smoothing (Gaussian kernel FWHM 10\xa0',
#   u'label': u'realign'},
#  {u'category': u'analysis',
#   u'context': u'uk/fsl). The BOLD scans were motion corrected and spatial smoothing (Gaussian kernel FWHM 10\xa0mm) was applied. BOLD',
#   u'label': u'spatsmoo'},
#  {u'category': u'analysis',
#   u'context': u'1/j.1467-9280.1997.tb00446.x.Cohen J. Statistical Power Analysis for the Behavior Sciences. 2nd ed. Hillsdale, NJ:',
#   u'label': u'power'},
#  {u'category': u'analysis',
#   u'context': u"icipant's anatomical (T1; mprage) scans, and then registered to standard space using the FSL's MNI (Montreal Neurologic In",
#   u'label': u'norm'},
#  {u'category': u'analysis',
#   u'context': u'er of presentation was randomized. We utilized an event-related\n                        design for the repetition priming paradigm, because it i',
#   u'label': u'event'},
#  {u'category': u'analysis',
#   u'context': u'ng paradigm, because it is more powerful than the block design for examining activation in\n                     ',
#   u'label': u'block'},
#  {u'category': u'tool',
#   u'context': u"stered first to that participant's anatomical (T1; mprage) scans, and then registered to standard space\n    ",
#   u'label': u'mprage'},
#  {u'category': u'analysis',
#   u'context': u', we further included, in this study, insula as a region of interest and tentatively hypothesized repetition priming e',
#   u'label': u'roi'},
#  {u'category': u'tool',
#   u'context': u"FMRI Expert Analysis) Tool, Version 5.90, part of FSL (FMRIB's Software Library, www.fmrib.ox.ac.uk/fsl",
#   u'label': u'fsl',
#   u'version': u'?'},
#  {u'category': u'tool',
#   u'context': u're importantly,\n                     the large RT variances in priming effects for the emotional and neutr',
#   u'label': u'varian'},
#  {u'category': u'analysis',
#   u'context': u'ary, www.fmrib.ox.ac.uk/fsl). The BOLD scans were motion corrected and spatial smoothing (Gaussian kernel FWHM 10\xa0',
#   u'label': u'realign'},
#  {u'category': u'analysis',
#   u'context': u'uk/fsl). The BOLD scans were motion corrected and spatial smoothing (Gaussian kernel FWHM 10\xa0mm) was applied. BOLD',
#   u'label': u'spatsmoo'},
#  {u'category': u'analysis',
#   u'context': u'stract/FREE Full Text\n\n\n\u21b5\n\n\nCohen J.\n Statistical Power Analysis for the Behavior Sciences. 2nd ed. Hillsdale, NJ:',
#   u'label': u'power'},
#  {u'category': u'analysis',
#   u'context': u"icipant's anatomical (T1; mprage) scans, and then registered to standard space\n                        using the FSL's MNI",
#   u'label': u'norm'},
#  {u'category': u'analysis',
#   u'context': u'er of presentation was randomized. We utilized an event-related design for the repetition priming paradigm, because it i',
#   u'label': u'event'},
#  {u'category': u'analysis',
#   u'context': u'ng paradigm, because it is more powerful than the block design for examining activation in response to single, s',
#   u'label': u'block'},
#  {u'category': u'tool',
#   u'context': u'istered \ufb01rst to that participant\u2019s anatomical (T1; mprage) scans, and then registered to standard space usin',
#   u'label': u'mprage'},
#  {u'category': u'analysis',
#   u'context': u', we further included, in this study, insula as a region of interest and tentatively hypothesized repetition priming e',
#   u'label': u'roi'},
#  {u'category': u'tool',
#   u'context': u'FMRI Expert Analysis) Tool, Version 5.90, part of FSL (FMRIB\u2019s Software Library, www.fmrib.ox.ac.uk/fsl',
#   u'label': u'fsl',
#   u'version': u'?'},
#  {u'category': u'tool',
#   u'context': u'nsistency. Perhaps more importantly, the large RT variances in priming effects for the emotional and neutr',
#   u'label': u'varian'},
#  {u'category': u'analysis',
#   u'context': u'ry, www.fmrib.ox.ac.uk/fsl ). The BOLD scans were motion corrected and spatial smoothing (Gaussian kernel FWHM 10 ',
#   u'label': u'realign'},
#  {u'category': u'analysis',
#   u'context': u'k/fsl ). The BOLD scans were motion corrected and spatial smoothing (Gaussian kernel FWHM 10 mm) was applied. BOLD',
#   u'label': u'spatsmoo'},
#  {u'category': u'analysis',
#   u'context': u'sychol Sci 8:322\u2013325. Cohen J. (1988) Statistical Power Analysis for the Behavior Sciences (2nd ed.). Hillsdale, N',
#   u'label': u'power'},
#  {u'category': u'analysis',
#   u'context': u'icipant\u2019s anatomical (T1; mprage) scans, and then registered to standard space using the FSL\u2019s MNI (Montreal Neurologic In',
#   u'label': u'norm'},
#  {u'category': u'analysis',
#   u'context': u'n corrected and spatial smoothing Gaussian kernel FWHM 10 mm was applied. BOLD scans for each participant were',
#   u'label': u'smooth_kernel',
#   u'value': 10.0}]

# %%
mongo.mr_all.find()[6]
# Out:
# {u'_id': {u'date': None, u'label': u'block'},
#  u'value': {u'ids': [u'526735f576eebde4999f5117',
#    u'526735f576eebde4999f5117',
#    u'526735f576eebde4999f5117',
#    u'5267312b76eebde4999f4fa7',
#    u'5267312b76eebde4999f4fa7',
#    u'52673ccf76eebde4999f535a',
#    u'52673ccf76eebde4999f535a',
#    u'52673ccf76eebde4999f535a',
#    u'5267479176eebde4999f572a',
#    u'5267479176eebde4999f572a',
#    u'526892db76eebd16c0d5c19c',
#    u'5269ec7d76eebd4852f60a82',
#    u'5269ec7d76eebd4852f60a82',
#    u'526a768076eebd4852f6128f',
#    u'526a768076eebd4852f6128f',
#    u'526a768076eebd4852f6128f',
#    u'526a966276eebd4852f61658',
#    u'526a966276eebd4852f61658',
#    u'526a966276eebd4852f61658',
#    u'526aad1676eebd4852f61b82',
#    u'526ac11176eebd829744a8fd',
#    u'526ac11176eebd829744a8fd',
#    u'526acb1a76eebd829744abbb',
#    u'526acb1a76eebd829744abbb']}}

# %%
list(mongo.mr_all.find())
# Out:
# [{u'_id': {u'date': None, u'label': u'aal'}, u'value': 111.0},
#  {u'_id': {u'date': None, u'label': u'aal', u'version': None},
#   u'value': 111.0},
#  {u'_id': {u'label': u'tempsmoo'}, u'value': 117.0},
#  {u'_id': {u'label': u'tfce'}, u'value': 13.0},
#  {u'_id': {u'label': u'varian'}, u'value': 1507.0},
#  {u'_id': {u'label': u'vbm'}, u'value': 108.0},
#  {u'_id': {u'label': u'vox'}, u'value': 917.0},
#  {u'_id': {u'label': u'voxbo'}, u'value': 19.0},
#  {u'_id': {u'label': u'voyager'}, u'value': 231.0},
#  {u'_id': {u'label': u'windows'}, u'value': 231.0},
#  {u'_id': {u'label': u'xjview'}, u'value': 8.0},
#  {u'_id': {u'label': [u'kernel[\\s\\-,]*?density[\\s\\-,]*?analysis']},
#   u'value': 60.0}]

# %%
from neurotrends.analysis import plot

# %%
from neurotrends import pattern
from neurotrends.analysis import analyze

# %%
pattern.tag_groups['pkg'].labels[0]
mongo.mr_all.find_one({'_id': {'label': 'cchips'}}) is None
pkg_counts = analyze.plot_tag_group(summary, pattern.tag_groups['pkg'])
pkg_counts
# Out:
# {'afni': 2392,
#  'caret': 358,
#  'cchips': 29,
#  'fiasco': 50,
#  'fidl': 29,
#  'fiswidgets': 14,
#  'fmristat': 153,
#  'fmrlab': 7,
#  'fsl': 1902,
#  'itk': 20,
#  'lipsia': 184,
#  'medx': 208,
#  'nipy': 12,
#  'pymvpa': 36,
#  'spm': 10903,
#  'suma': 120,
#  'surfer': 537,
#  'voxbo': 120,
#  'voyager': 1692}

# %%
import pandas as pd
import vincent
vincent.core.initialize_notebook()

df_pkg = pd.DataFrame([{k: v} for k, v in pkg_counts.items()])

data = []
for idx, key in enumerate(pkg_counts):
    data.append({
        'name': key,
        'count': pkg_counts[key]
    })
#print data
bar = vincent.Bar(pd.DataFrame(data, index=range(len(data))))
print bar.scales[0].__dict__
#bar.colors(brew='Set3')
#bar.axis_titles(x='Index', y='Value')
bar.display()
# Out:
# {'grammar': {'range': 'width', 'domain': <vincent.scales.DataRef object at 0x10f217b50>, 'type': 'ordinal', 'name': 'x'}}
# <div id="vis45372"></div>

# %%
data, any_data, dates, date_counts, display_labels = analyze.plot_tag_group_year(
    summary, pattern.tag_groups['pkg'].labels, range(1997, 2014), 
    include_none=False, min_prop=0.01
)

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(data, index=dates, columns=display_labels)
print df

ax = df.plot(kind='bar', stacked=True, figsize=[7,6])
handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles[::-1], labels[::-1], loc='upper left', bbox_to_anchor=(1, 1))

plt.savefig('/Users/jmcarp/Desktop/samplefigure2', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
#        spm  afni  fsl  voyager  surfer  caret  medx  other
# 1997    14     6    0        0       0      0     0      0
# 1998    51    12    0        1       0      0     1      1
# 1999   100    21    3        6       0      1    12      0
# 2000   155    37    3       10       0      1    17      6
# 2001   211    57    6       17       2      1    18     17
# 2002   296    61   19       42       2      3    34     31
# 2003   431    90   19       46      10     10    34     29
# 2004   503   126   32       64      14      7    24     36
# 2005   666   113   51      107      18     18    15     64
# 2006   751   155   81      128      25     22    10     66
# 2007   852   171  134      166      38     24     9     79
# 2008   926   205  125      171      39     40     6     84
# 2009  1059   227  214      182      53     42     5     67
# 2010  1228   232  246      204      67     42     7     64
# 2011  1281   299  321      216      89     51     1     78
# 2012  1413   351  409      200     117     56     3     95
# 2013   614   153  192       93      55     32     0     35

# %%
#%%time
import pandas as pd
import vincent
vincent.core.initialize_notebook()

pkg_counts, any_data, dates, labels = analyze.plot_tag_group_year(
    summary, pattern.tag_groups['pkg'].labels, range(1997, 2014), 
    include_none=False, min_prop=0.01
)
#pkg_counts, dates, labels = plot.plot_tag_group_year(summary, ['power'], norm=True)
from vincent.legends import Legend
from vincent import ValueRef, PropertySet, AxisProperties
from vincent.legends import LegendProperties
df = pd.DataFrame(pkg_counts, index=dates, columns=labels)
sbar = vincent.StackedBar(df, height=600, width=600)
sbar.legends.append(Legend(values=labels[::-1], fill='color'))
sbar.legends[0].properties = LegendProperties(
    size=ValueRef(value=18)
)
sbar.colors(brew='Set1')

sbar.axes[0].properties = AxisProperties(labels=PropertySet(
    angle=ValueRef(value=-45), 
    dx=ValueRef(value=-20), 
    font_size=ValueRef(value=18)
))

sbar.scales['y'].domain = [0, 1]
sbar.display()

df = pd.DataFrame(any_data, index=dates)
sbar = vincent.StackedBar(df, height=600, width=600)
sbar.scales['y'].domain = [0, 1]
sbar.display()

#sbar.to_json('/Users/jmcarp/Desktop/test.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-9ae35a889534> in <module>()
#       6 pkg_counts, any_data, dates, labels = analyze.plot_tag_group_year(
#       7     summary, pattern.tag_groups['pkg'].labels, range(1997, 2014),
# ----> 8     include_none=False, min_prop=0.01
#       9 )
#      10 #pkg_counts, dates, labels = plot.plot_tag_group_year(summary, ['power'], norm=True)
#
# ValueError: too many values to unpack

# %%
article = mongo['article'].find_one({'pmid': '17360198'})
article['tags']
# Out:
# [{u'category': u'tool',
#   u'context': u'his, we used the k-means algorithm implemented in Matlab 7.4 (Mathworks, Natick, MA) with the v\xa0\xd7\xa02 matrix of ',
#   u'label': u'matlab',
#   u'version': u'7.4'},
#  {u'category': u'analysis',
#   u'context': u'has proven particularly powerful for dealing with event-related designs, as a sequence of sparse events occurring at ran',
#   u'label': u'event'},
#  {u'category': u'analysis',
#   u'context': u'subject to the limitations in interpretability of block designs, and only states that are under relatively preci',
#   u'label': u'block'},
#  {u'category': u'analysis',
#   u'context': u' et al., in press\xa0and\xa0Worsley and Friston, 1995). Mixed block/event-related designs have been used to investigate sta',
#   u'label': u'mixed'},
#  {u'category': u'analysis',
#   u'context': u"m calculated using Satterthwaite's approximation. Family-wise error rate (FWER) control across the time series is pro",
#   u'label': u'fwe'},
#  {u'category': u'analysis',
#   u'context': u'ocorrelated noise models.VALIDHTMLFinally, we use false discovery rate (FDR) control (Genovese et al., 2002) to correct ',
#   u'label': u'fdr'},
#  {u'category': u'analysis',
#   u'context': u'st be controlled for search over the time series. Bonferroni correction is overly conservative because of posi',
#   u'label': u'bon'},
#  {u'category': u'tool',
#   u'context': u'ortex. High-resolution T1 spoiled gradient recall (SPGR) images were acquired for anatomical localization ',
#   u'label': u'spgr'},
#  {u'category': u'tool',
#   u'context': u'weighted, single-shot reverse spiral acquisition (gradient echo, TR\xa0=\xa02000, TE\xa0=\xa030, flip angle\xa0=\xa090\xb0) with 40 se',
#   u'label': u'gradient'},
#  {u'category': u'tool',
#   u'context': u'cquired using a T2*-weighted, single-shot reverse spiral acquisition (gradient echo, TR\xa0=\xa02000, TE\xa0=\xa030, f',
#   u'label': u'spiral'},
#  {u'category': u'analysis',
#   u'context': u'I data voxel-wise throughout the brain, data from regions of interest, or temporal components extracted using ICA or si',
#   u'label': u'roi'},
#  {u'category': u'analysis',
#   u'context': u'The HEWMA method can be used to analyze fMRI data voxel-wise throughout the brain, data from regions of intere',
#   u'label': u'vox'},
#  {u'category': u'analysis',
#   u'context': u'data-driven approach in the fMRI community is the independent components analysis (ICA), a variant on a family of analyses that als',
#   u'label': u'ica'},
#  {u'category': u'analysis',
#   u'context': u'r time and may differ among subjects.VALIDHTMLThe multi-level model can be written in single-level format as:eq',
#   u'label': [u'kernel[\\s\\-,]*?density[\\s\\-,]*?analysis']},
#  {u'category': u'tool',
#   u'context': u'ReML). Our approach is equivalent to that used in SPM2 (Friston et al., 2002), which uses an EM-algorith',
#   u'label': u'spm',
#   u'version': u'2'},
#  {u'category': u'tool',
#   u'context': u'rom 30 participants scanned with BOLD fMRI at 3\xa0T (GE, Milwaukee, WI). The experiment was conducted in a',
#   u'label': u'ge'},
#  {u'category': u'tool',
#   u'context': u'y is the independent components analysis (ICA), a variant on a family of analyses that also includes princ',
#   u'label': u'varian'},
#  {u'category': u'analysis',
#   u'context': u'\u03bb(1\u2212(1\u2212\u03bb)2t)mathContainerLoading MathjaxCommentFor AR(1) noise, the minimum autocorrelation model appropri',
#   u'label': u'autocorr'},
#  {u'category': u'analysis',
#   u'context': u'sed on the EWMA statistic, zt. The statistic is a temporally smoothed version of the data, and is defined as follows:',
#   u'label': u'tempsmoo'},
#  {u'category': u'analysis',
#   u'context': u'ces using a custom 4-point sync interpolation and realigned (motion-corrected) to the first image using Aut',
#   u'label': u'realign'},
#  {u'category': u'analysis',
#   u'context': u'onal images, which were then smoothed with a 9-mm isotropic Gaussian kernel.VALIDHTMLIndividual-subject data were subj',
#   u'label': u'spatsmoo'},
#  {u'category': u'analysis',
#   u'context': u'001), pp. 1136\u20131149Cohen, 1988J. CohenStatistical Power Analysis for the Behavioral Sciences (2nd ed.)Erlbaum, Hil',
#   u'label': u'power'},
#  {u'category': u'analysis',
#   u'context': u'ges were acquired for anatomical localization and warping to standard space.VALIDHTMLImage analysisOffline image recons',
#   u'label': u'norm'},
#  {u'category': u'analysis',
#   u'context': u'used by magnetic field inhomogeneity. Images were corrected for slice acquisition timing differences using a custom 4-p',
#   u'label': u'stc'},
#  {u'category': u'analysis',
#   u'context': u'ation (AIR; Woods et al., 1998). SPGR images were co-registered to the first functional image using a mutual ',
#   u'label': u'coreg'},
#  {u'category': u'analysis',
#   u'context': u'n treating psychological activity as a zero-error fixed effect specified by the analyst (as in GLM analysis) and',
#   u'label': u'ffx'},
#  {u'category': u'tool',
#   u'context': u'his, we used the k-means algorithm implemented in Matlab 7.4 (Mathworks, Natick, MA) with the v \xd7 2 matrix of ',
#   u'label': u'matlab',
#   u'version': u'7.4'},
#  {u'category': u'analysis',
#   u'context': u'has proven particularly powerful for dealing with eventrelated designs, as a sequence of sparse events occurring at ran',
#   u'label': u'event'},
#  {u'category': u'analysis',
#   u'context': u'subject to the limitations in interpretability of block designs, and only states that are under relatively preci',
#   u'label': u'block'},
#  {u'category': u'analysis',
#   u'context': u'ger et al., in press; Worsley and Friston, 1995). Mixed block/event-related designs have been used to investigate sta',
#   u'label': u'mixed'},
#  {u'category': u'analysis',
#   u'context': u'm calculated using Satterthwaite\u2019s approximation. Family-wise error rate (FWER) control across the time series is pro',
#   u'label': u'fwe'},
#  {u'category': u'analysis',
#   u'context': u'ally autocorrelated noise models. Finally, we use false discovery rate (FDR) control (Genovese et al., 2002) to correct ',
#   u'label': u'fdr'},
#  {u'category': u'analysis',
#   u'context': u'st be controlled for search over the time series. Bonferroni correction is overly conservative because of posi',
#   u'label': u'bon'},
#  {u'category': u'tool',
#   u'context': u'ortex. High-resolution T1 spoiled gradient recall (SPGR) images were acquired for anatomical localization ',
#   u'label': u'spgr'},
#  {u'category': u'tool',
#   u'context': u'weighted, single-shot reverse spiral acquisition (gradient echo, TR = 2000, TE = 30, flip angle = 90\xb0) with 40 se',
#   u'label': u'gradient'},
#  {u'category': u'tool',
#   u'context': u'cquired using a T2*-weighted, single-shot reverse spiral acquisition (gradient echo, TR = 2000, TE = 30, f',
#   u'label': u'spiral'},
#  {u'category': u'analysis',
#   u'context': u'I data voxel-wise throughout the brain, data from regions of interest, or temporal components extracted using ICA or si',
#   u'label': u'roi'},
#  {u'category': u'analysis',
#   u'context': u'The HEWMA method can be used to analyze fMRI data voxel-wise throughout the brain, data from regions of intere',
#   u'label': u'vox'},
#  {u'category': u'analysis',
#   u'context': u'data-driven approach in the fMRI community is the independent components analysis (ICA), a variant on a family of analyses that als',
#   u'label': u'ica'},
#  {u'category': u'analysis',
#   u'context': u'oImage 35 (2007) 1125\u20131141 1131 i s pop \xfe Y n The multi-level model can be written in single-level format as: s',
#   u'label': [u'kernel[\\s\\-,]*?density[\\s\\-,]*?analysis']},
#  {u'category': u'tool',
#   u'context': u'ReML). Our approach is equivalent to that used in SPM2 (Friston et al., 2002), which uses an EM-algorith',
#   u'label': u'spm',
#   u'version': u'2'},
#  {u'category': u'tool',
#   u'context': u'ata from 30 participants scanned with BOLD fMRI at 3 T (GE, Milwaukee, WI). The experiment was conducted',
#   u'label': u'field_strength',
#   u'value': 3.0},
#  {u'category': u'tool',
#   u'context': u'rom 30 participants scanned with BOLD fMRI at 3 T (GE, Milwaukee, WI). The experiment was conducted in a',
#   u'label': u'ge'},
#  {u'category': u'tool',
#   u'context': u'y is the independent components analysis (ICA), a variant on a family of analyses that also includes princ',
#   u'label': u'varian'},
#  {u'category': u'analysis',
#   u'context': u't et al. / NeuroImage 35 (2007) 1125\u20131141 1129 For AR(1) noise, the minimum autocorrelation model appropri',
#   u'label': u'autocorr'},
#  {u'category': u'analysis',
#   u'context': u'e EWMA statistic, zt. The statistic is mean. It a temporally smoothed version of the data, and is defined as follows:',
#   u'label': u'tempsmoo'},
#  {u'category': u'analysis',
#   u'context': u'ces using a custom 4-point sync interpolation and realigned (motion-corrected) to the first image using Aut',
#   u'label': u'realign'},
#  {u'category': u'analysis',
#   u'context': u'onal images, which were then smoothed with a 9-mm isotropic Gaussian kernel. Individual-subject data were subjected to',
#   u'label': u'spatsmoo'},
#  {u'category': u'analysis',
#   u'context': u'e 14 (5), 1136\u20131149. Cohen, J., 1988. Statistical Power Analysis for the Behavioral Sciences, 2nd ed. Erlbaum, Hil',
#   u'label': u'power'},
#  {u'category': u'analysis',
#   u'context': u'ges were acquired for anatomical localization and warping to standard space. Image analysis Offline image reconstructio',
#   u'label': u'norm'},
#  {u'category': u'analysis',
#   u'context': u'used by magnetic field inhomogeneity. Images were corrected for slice acquisition timing differences using a custom 4-p',
#   u'label': u'stc'},
#  {u'category': u'analysis',
#   u'context': u'ation (AIR; Woods et al., 1998). SPGR images were co-registered to the first functional image using a mutual ',
#   u'label': u'coreg'},
#  {u'category': u'analysis',
#   u'context': u'n treating psychological activity as a zero-error fixed effect specified by the analyst (as in GLM analysis) and',
#   u'label': u'ffx'}]

# %%
# %%time
import collections
pipelines = collections.defaultdict(int)

for article in mongo['article'].find({'tags': {'$ne': []}}, {'tags': 1}):
    tags = [
        frozenset([
            (key, value)
            for key, value in tag.items()
            if key != 'context'
                and not isinstance(value, list)
        ])
        for tag in article['tags']
    ]
    frozen_tags = frozenset(tags)
    pipelines[frozen_tags] += 1

# import pprint
# pprint.pprint(pipelines)
#print pipelines.values()
# Out:
# CPU times: user 549 ms, sys: 43.5 ms, total: 592 ms
# Wall time: 617 ms

# %%
df2 = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot(kind='bar', stacked=True)

# %%
# %%time
label_counts = collections.defaultdict(list)
label_version_counts = collections.defaultdict(list)
label_date_counts = collections.defaultdict(list)
label_version_date_counts = collections.defaultdict(list)
for article in mongo['article'].find({'tags': {'$ne': []}}, {'tags': 1, 'date': 1}):
    for tag in article['tags']:
        if isinstance(tag['label'], list):
            continue
        label_counts[tag['label']].append(article['_id'])
        if 'version' in tag:
            label_version_counts[(tag['label'], tag['version'])].append(article['_id'])
        if 'date' in tag:
            label_date_counts[(tag['label'], tag['date'].year)].append(article['_id'])
        if 'version' in tag and 'date' in tag:
            label_version_date_counts[(tag['label'], tag['version'], tag['date'].year)].append(article['_id'])
# Out:
# CPU times: user 357 ms, sys: 48.8 ms, total: 405 ms
# Wall time: 462 ms

# %%
print {key: len(value) for key, value in label_counts.items()}
# Out:
# {u'roi': 3253, u'mprage': 1124, u'ffx': 521, u'localizer': 582, u'ale': 12, u'monte': 280, u'highpass_cutoff': 385, u'ge': 1625, u'superlab': 31, u'fir': 112, u'spmd': 1, u'lipsia': 49, u'autocorr': 538, u'fortran': 2, u'matlab': 1392, u'hrf': 369, u'presentation': 361, u'norm': 3546, u'smash': 12, u'python': 32, u'winsor': 8, u'inquisit': 7, u'siemens': 2478, u'psychtoolbox': 134, u'motreg': 89, u'rest': 23, u'mricron': 199, u'suma': 38, u'pickatlas': 280, u'daemon': 220, u'spatsmoo': 3268, u'artrepair': 10, u'gift': 43, u'rft': 459, u'rfx': 76, u'visionegg': 2, u'directrt': 3, u'cchips': 5, u'strip': 339, u'fiswidgets': 9, u'sem': 130, u'event': 2363, u'gradient': 2838, u'ica': 585, u'realign': 3996, u'surfrend': 2, u'medx': 61, u'dcm': 182, u'pls': 76, u'power': 86, u'despike': 53, u'surfer': 187, u'varian': 3195, u'snpm': 21, u'voxbo': 44, u'psyscope': 103, u'xjview': 17, u'eprime': 405, u'pymvpa': 14, u'fwe': 595, u'vbm': 266, u'filter': 1639, u'idl': 73, u'bon': 730, u'mixed': 75, u'block': 1684, u'ppi': 187, u'mvpa': 278, u'desopt': 107, u'linux': 116, u'caret': 124, u'java': 77, u'spiral': 307, u'suit': 2, u'marsbar': 385, u'tfce': 28, u'gscale': 33, u'afni': 714, u'spin': 540, u'pca': 312, u'stc': 1171, u'aal': 219, u'bruker': 202, u'tempsmoo': 230, u'grase': 17, u'fdr': 735, u'coreg': 2071, u'spm': 3116, u'sense': 247, u'conj': 629, u'vox': 1914, u'fmrlab': 4, u'stim': 5, u'cogent': 77, u'fmristat': 52, u'grc': 90, u'fidl': 14, u'voyager': 492, u'field_strength': 4670, u'epi': 4193, u'spgr': 324, u'betser': 17, u'estsmoo': 53, u'mac': 21, u'marconi': 56, u'segment': 114, u'mnital': 163, u'philips': 553, u'presto': 36, u'windows': 455, u'rlang': 63, u'fsl': 548, u'svc': 458, u'smooth_kernel': 2359, u'fiasco': 13, u'grappa': 96}

# %%
# %%time
mongo['article'].find({'tags': {'$elemMatch': {'label': 'spm', 'version': '5'}}}).count()
# Out:
# CPU times: user 729 µs, sys: 68 µs, total: 797 µs
# Wall time: 18.8 ms
# 376

# %%
def summarize():
    
    summary = collections.defaultdict(list)
    
    for article in mongo['article'].find({'tags': {'$ne': []}}, {'tags': 1, 'date': 1}):
        
        for tag in article['tags']:
            
            if isinstance(tag['label'], list):
                continue

            _id = article['_id']
            label = tag['label']
            version = tag.get('version')
            date = article['date'].year if article['date'] else None

            summary[(label,)].append(_id)
            summary[(label, date)].append(_id)
            if version:
                summary[(label, version)].append(_id)
                summary[(label, date, version)].append(_id)
    
    return summary

# %time summary = summarize()
# Out:
# CPU times: user 3.8 s, sys: 370 ms, total: 4.17 s
# Wall time: 4.45 s

# %%
len(summary[('afni',)])
# Out:
# 2392

# %%
mongo['article'].find_one({'tags': {'$ne': []}}, {'tags': 1, 'date': 1})
# Out:
# {u'_id': u'5267374576eebde4999f5191',
#  u'date': datetime.datetime(2008, 10, 22, 0, 0),
#  u'tags': [{u'category': u'tool',
#    u'context': u'ealthy subjects\u2019 group and in each patient, using SPM5. Results: One patient in VS and one in MCS showed',
#    u'label': u'spm',
#    u'version': u'5'}]}

# %%
# %%time
import collections
pipelines = collections.defaultdict(int)
pipelines_year = collections.defaultdict(lambda: collections.defaultdict(int))
total_year = collections.defaultdict(int)

pipelines_group = collections.defaultdict(
    lambda: collections.defaultdict(int)
)

pipelines_group_year = collections.defaultdict(
    lambda: collections.defaultdict(
        lambda: collections.defaultdict(int)
    )
)

variance_groups = {
    name: group.labels 
    for name, group in pattern.tag_groups.items()
}

def cat_labels(names, groups):
    return sum([
        groups[name].labels
        for name in names
    ], [])

variance_groups['all'] = cat_labels(
    pattern.tag_groups.keys(),
    pattern.tag_groups
)

variance_groups['collection'] = cat_labels(
    ['mag', 'pulse', 'task', 'des'],
    pattern.tag_groups
)

variance_groups['analysis'] = cat_labels(
    ['pkg', 'proc', 'mod', 'mcc', 'tech'], 
    pattern.tag_groups
)

for article in mongo['article'].find({'tags': {'$ne': []}}, {'tags': 1, 'date': 1}):
    
    date = article.get('date')
    year = date.year if date else None
    
    #group_data = collections.defaultdict(list)
    group_data = collections.defaultdict(tuple)
    
    total_year[year] += 1
    
    for tag in article['tags']:
        
        frozen_tag = [
            (key, value)
            for key, value in tag.items()
            if key != 'context'
                and not isinstance(value, list)
        ]
        
        for group_name, labels in variance_groups.items():
            if tag['label'] in labels:
                #group_data[group_name].append(frozen_tag)
                group_data[group_name] += tuple(frozen_tag)
    
    for group_name in variance_groups.keys():
        #frozen_tags = frozenset(group_data[group_name])
        frozen_tags = group_data[group_name]
        if frozen_tags:
            pipelines_group[group_name][frozen_tags] += 1
            pipelines_group_year[group_name][year][frozen_tags] += 1
# Out:
# CPU times: user 1.07 s, sys: 20.2 ms, total: 1.09 s
# Wall time: 1.1 s

# %%
years = range(1995, 2014)
print ['%02d' % total_year[y] for y in years]
print ['%02d' % len(pipelines_group_year['all'][y]) for y in years]
print ['%02d' % len(pipelines_group_year['collection'][y]) for y in years]
print ['%02d' % len(pipelines_group_year['analysis'][y]) for y in years]
print ['%02d' % len(pipelines_group_year['proc'][y]) for y in years]
# Out:
# ['01', '02', '05', '05', '08', '22', '15', '23', '30', '22', '53', '40', '48', '57', '62', '89', '92', '93', '43']
# ['01', '02', '05', '05', '08', '22', '15', '23', '30', '22', '53', '40', '48', '57', '62', '89', '92', '93', '43']
# ['01', '02', '05', '05', '08', '21', '15', '23', '29', '20', '50', '39', '47', '53', '57', '83', '82', '85', '41']
# ['01', '01', '05', '04', '08', '21', '14', '22', '29', '21', '52', '38', '45', '55', '62', '89', '91', '93', '43']
# ['01', '01', '04', '03', '05', '19', '10', '21', '25', '16', '39', '35', '35', '49', '51', '76', '68', '74', '38']

# %%
# %time m = mongo['article'].find_one({'_id': '526a03c376eebd4852f61026'})
Article._clear_caches()
# %time o = Article.find_one(Q('_id', 'eq', '526a03c376eebd4852f61026'))
# %time o1 = Article.find_one(Q('_id', 'eq', '526a03c376eebd4852f61026'))
Article._clear_caches()
# %time o2 = Article.load('526a03c376eebd4852f61026')
# %time o3 = Article.load('526a03c376eebd4852f61026')
# Out:
# CPU times: user 598 µs, sys: 71 µs, total: 669 µs
# Wall time: 914 µs
# CPU times: user 2.29 ms, sys: 79 µs, total: 2.37 ms
# Wall time: 2.75 ms
# CPU times: user 951 µs, sys: 74 µs, total: 1.03 ms
# Wall time: 1.26 ms
# CPU times: user 1.42 ms, sys: 52 µs, total: 1.47 ms
# Wall time: 1.65 ms
# CPU times: user 159 µs, sys: 1 µs, total: 160 µs
# Wall time: 167 µs

# %%
query = Article.find().limit(20)

Article._clear_caches()

# %time foo = list(query)
# %time foo = list(query)

Article._clear_caches()
# %time bar = [Article.load(_id) for _id in list(query.__iter__(raw=True))]
# %time bar = [Article.load(_id) for _id in list(query.__iter__(raw=True))]
# Out:
# CPU times: user 23.6 ms, sys: 902 µs, total: 24.5 ms
# Wall time: 27.2 ms
# CPU times: user 5.06 ms, sys: 226 µs, total: 5.28 ms
# Wall time: 5.74 ms
# CPU times: user 21.4 ms, sys: 1.12 ms, total: 22.5 ms
# Wall time: 26.8 ms
# CPU times: user 2.52 ms, sys: 91 µs, total: 2.61 ms
# Wall time: 2.89 ms

# %%
# %%time
Article._clear_caches()
# articles = list(Article.find(Q('tags.label', 'eq', 'spm')).limit(10))
articles = list(mongo['article'].find({'tags.label': 'spm'})[1000:1010])
#print articles
# print articles[0]._id
# Out:
# CPU times: user 2.04 ms, sys: 103 µs, total: 2.14 ms
# Wall time: 11.3 ms

# %%
def summarize_custom(articles, func):

    summary = collections.defaultdict(list)

    for article in articles:

        _id = article['_id']

        for tag in article['tags']:

            out = func(tag)
            date = article['date'].year if article['date'] else None

            if out is not None:
                summary[(out,)].append(_id)
                summary[(out, date)].append(_id)
    
    return summary

def field_summary(tag):

    if tag['label'] == 'field_strength':
        return round(tag['value'] * 2.0) / 2

# %%
articles = mongo['article'].find({'tags': {'$ne': []}}, {'tags': 1, 'date': 1})
# %time s = summarize_custom(articles, field_summary)
# Out:
# CPU times: user 294 ms, sys: 40.9 ms, total: 335 ms
# Wall time: 358 ms

# %%
print {k: len(v) for k, v in s.items()}
# Out:
# {(7.0, 2011): 17, (4.0, 1998): 3, (0.5,): 4, (4.0, 2009): 29, (2.0, 2008): 2, (3.0, 2010): 320, (4.0, 2004): 14, (1.5, 2007): 145, (1.5, 2010): 131, (1.5, 1997): 15, (7.0,): 114, (1.5, 2012): 122, (2.0, 2013): 2, (3.0, 2009): 248, (9.5, 2004): 4, (8.0,): 2, (3.0, None): 203, (3.5,): 1, (7.0, 2000): 1, (4.5, None): 1, (7.0, 2013): 5, (3.0, 1998): 3, (1.5,): 1879, (2.0, 2003): 16, (4.0, 2003): 20, (9.5, 2011): 2, (1.0, 2000): 1, (3.0, 2004): 40, (9.5, 2001): 1, (2.0, 1997): 4, (7.0, 2007): 2, (3.0, 1997): 1, (2.0, 2004): 9, (4.0, 2000): 9, (1.0, 2003): 1, (3.0, 2003): 54, (2.0, 1998): 2, (4.5, 2010): 3, (1.5, 2001): 76, (7.0, 2010): 16, (1.5, None): 192, (2.0, None): 14, (4.0, 2010): 32, (0.5, 2007): 1, (2.0, 2009): 3, (3.0, 2013): 176, (4.0, 2005): 24, (1.5, 2011): 138, (1.5, 1998): 16, (7.0, 2009): 16, (8.0, 2012): 1, (1.0, 2004): 2, (2.0, 2010): 4, (3.0, 2008): 220, (1.5, 2005): 160, (1.0, 2009): 2, (2.0,): 114, (1.5, 2008): 136, (7.0, 2003): 2, (1.5, 1995): 8, (1.5, 2000): 58, (7.0, 2012): 28, (2.0, 2000): 9, (4.0, 2012): 27, (1.5, 2006): 159, (3.0, 2007): 148, (1.5, 2002): 64, (7.0, 2006): 2, (4.0, 1995): 1, (5.0, 2000): 1, (2.0, 2005): 4, (4.0, 2001): 6, (1.0, 2002): 2, (4.5, 2009): 2, (3.0, 2002): 20, (2.0, 1999): 9, (3.0, 1999): 11, (4.5,): 7, (1.5, 2004): 107, (4.0, 2011): 24, (4.0, None): 43, (1.5, 2009): 141, (2.0, 2006): 6, (3.0, 2012): 475, (4.0, 2006): 22, (3.0, 2001): 12, (4.5, 2012): 1, (9.5, None): 1, (1.5, 1999): 50, (7.0, 2008): 7, (4.0,): 332, (4.0, 1997): 2, (5.0, 2009): 1, (4.0, 2008): 20, (2.0, 2011): 4, (3.0, 2011): 400, (0.5, 2006): 1, (1.0, 2008): 1, (9.5, 2008): 2, (9.5, 2009): 1, (1.5, 1996): 5, (7.0, 2005): 7, (8.0, 2010): 1, (2.0, 2001): 10, (4.0, 2013): 3, (9.5,): 18, (1.0, 2006): 2, (2.0, 2012): 3, (3.0, 2006): 92, (1.5, 2003): 123, (1.0, 2011): 1, (5.0,): 2, (7.0, 2001): 1, (1.0, None): 3, (7.0, None): 6, (2.0, 2002): 10, (4.0, 2002): 17, (1.0, 2001): 2, (3.0, 2005): 115, (0.5, 2000): 2, (3.0,): 2554, (9.5, 2010): 7, (7.0, 2004): 4, (1.0,): 18, (1.5, 2013): 33, (2.0, 2007): 3, (4.0, 2007): 26, (1.0, 2012): 1, (3.0, 2000): 16, (3.5, 2013): 1, (4.0, 1999): 10}

# %%
steps = ['realign', 'norm', 'spatsmoo', 'strip', 'stc']
articles = mongo['article'].find({'tags.label': {'$in': steps}})
sequences = []
sequence_counts = collections.defaultdict(int)
for article in articles:
    sequence = []
    for tag in article['tags']:
        if tag['label'] in steps and 'span' in tag:
            sequence.append((tag['label'], sum(tag['span']) / 2.0))
    sequence = [
        step[0]
        for step in sorted(sequence, key=lambda item: key[1])
    ]
    sequences.append(sequence)
    sequence_counts[tuple(sequence)] += 1

# %%
sequence_counts.keys()
#ordered = sorted(sequence_counts.keys, key=lambda item: sequence_counts[item])
# Out:
# [(u'spatsmoo', u'norm', u'spatsmoo', u'norm', u'norm'),
#  (u'strip', u'strip', u'realign', u'norm', u'spatsmoo', u'norm', u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'norm'),
#  (u'spatsmoo', u'spatsmoo', u'spatsmoo'),
#  (u'realign', u'norm', u'realign', u'norm', u'realign', u'spatsmoo', u'norm'),
#  (u'spatsmoo', u'norm', u'spatsmoo', u'norm'),
#  (u'realign', u'norm', u'norm'),
#  (),
#  (u'realign', u'spatsmoo', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'norm', u'stc', u'realign', u'stc'),
#  (u'spatsmoo', u'norm', u'stc'),
#  (u'realign', u'norm', u'realign', u'realign', u'norm'),
#  (u'norm', u'norm', u'norm', u'norm'),
#  (u'realign', u'norm', u'spatsmoo'),
#  (u'realign', u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'stc', u'spatsmoo', u'norm', u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'stc'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'norm', u'norm', u'stc', u'realign', u'norm', u'norm', u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'norm'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'norm'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip', u'spatsmoo', u'strip', u'spatsmoo', u'strip', u'spatsmoo'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'stc'),
#  (u'strip', u'realign', u'spatsmoo', u'norm'),
#  (u'strip', u'strip', u'realign', u'strip', u'strip', u'realign', u'spatsmoo'),
#  (u'spatsmoo', u'norm', u'spatsmoo', u'norm', u'spatsmoo', u'norm'),
#  (u'strip',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign', u'spatsmoo', u'norm', u'stc', u'realign', u'spatsmoo', u'norm'),
#  (u'spatsmoo',),
#  (u'realign', u'norm', u'realign', u'norm'),
#  (u'realign', u'norm', u'norm', u'stc'),
#  (u'strip', u'strip', u'realign', u'strip', u'strip', u'realign'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'spatsmoo'),
#  (u'realign', u'norm', u'norm', u'realign', u'spatsmoo', u'norm', u'norm'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'norm',
#   u'spatsmoo'),
#  (u'spatsmoo', u'norm', u'stc', u'spatsmoo', u'norm', u'stc'),
#  (u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip', u'strip', u'strip', u'strip'),
#  (u'realign', u'norm', u'realign', u'spatsmoo', u'norm', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'spatsmoo',
#   u'norm'),
#  (u'spatsmoo', u'spatsmoo', u'norm'),
#  (u'norm', u'stc'),
#  (u'realign', u'stc', u'realign', u'stc', u'realign', u'stc'),
#  (u'realign', u'spatsmoo', u'norm', u'norm', u'realign', u'norm', u'norm'),
#  (u'strip', u'realign', u'norm', u'strip', u'realign'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'norm', u'stc', u'realign', u'norm', u'norm', u'stc'),
#  (u'realign', u'norm', u'norm', u'realign'),
#  (u'realign', u'spatsmoo', u'realign', u'spatsmoo', u'spatsmoo'),
#  (u'stc',),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm'),
#  (u'strip', u'realign', u'spatsmoo'),
#  (u'norm', u'norm', u'stc', u'norm', u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'spatsmoo', u'stc', u'spatsmoo', u'stc'),
#  (u'realign', u'spatsmoo', u'norm', u'realign'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip', u'strip', u'strip'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'norm', u'spatsmoo'),
#  (u'realign', u'spatsmoo', u'realign'),
#  (u'strip', u'realign', u'spatsmoo', u'strip', u'realign', u'spatsmoo'),
#  (u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign', u'norm', u'norm', u'realign', u'norm', u'norm'),
#  (u'realign', u'stc', u'realign', u'norm', u'stc'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo'),
#  (u'norm', u'strip', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'norm', u'norm', u'norm', u'norm', u'norm', u'norm'),
#  (u'realign', u'realign'),
#  (u'realign', u'norm', u'realign'),
#  (u'strip', u'realign', u'strip', u'realign'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'strip', u'realign', u'norm', u'strip', u'realign', u'norm', u'norm'),
#  (u'realign', u'norm', u'norm', u'realign', u'norm'),
#  (u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip', u'strip', u'norm', u'norm', u'strip', u'strip', u'norm', u'norm'),
#  (u'norm', u'norm', u'norm'),
#  (u'strip',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'realign', u'spatsmoo'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'stc', u'realign', u'norm', u'stc', u'realign', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'realign', u'norm'),
#  (u'strip', u'spatsmoo', u'strip', u'spatsmoo'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'norm', u'stc', u'norm', u'stc', u'norm', u'stc'),
#  (u'realign', u'spatsmoo', u'norm', u'stc', u'realign', u'norm', u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'spatsmoo', u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'realign', u'norm', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip',),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'strip',
#   u'realign',
#   u'spatsmoo'),
#  (u'realign', u'spatsmoo', u'norm', u'norm', u'realign', u'spatsmoo', u'norm'),
#  (u'norm', u'spatsmoo', u'norm'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'realign', u'norm', u'realign', u'norm', u'realign', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'strip', u'realign', u'strip', u'realign', u'strip', u'realign'),
#  (u'norm', u'norm', u'norm', u'norm', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'strip', u'realign', u'spatsmoo', u'norm', u'norm', u'stc'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'realign',
#   u'norm',
#   u'spatsmoo'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'strip',
#   u'realign',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'norm'),
#  (u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign', u'norm', u'spatsmoo', u'realign', u'norm', u'spatsmoo'),
#  (u'norm', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'realign', u'norm', u'stc', u'realign', u'spatsmoo', u'norm', u'stc'),
#  (u'realign', u'norm', u'spatsmoo', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'spatsmoo', u'norm', u'spatsmoo', u'spatsmoo', u'norm'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'norm', u'realign', u'realign', u'norm'),
#  (u'strip',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'stc'),
#  (u'realign', u'stc', u'realign', u'stc'),
#  (u'norm', u'stc', u'norm', u'stc'),
#  (u'realign', u'norm', u'norm', u'realign', u'norm', u'norm', u'realign'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign', u'spatsmoo', u'norm', u'norm', u'stc'),
#  (u'realign', u'spatsmoo'),
#  (u'spatsmoo', u'norm', u'stc', u'spatsmoo', u'norm', u'norm', u'stc'),
#  (u'realign', u'spatsmoo', u'norm'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'realign', u'realign'),
#  (u'spatsmoo', u'spatsmoo'),
#  (u'strip', u'realign', u'spatsmoo', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'realign', u'spatsmoo', u'norm'),
#  (u'stc', u'realign', u'norm', u'norm', u'stc', u'realign', u'norm', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign', u'norm', u'spatsmoo', u'realign', u'norm', u'spatsmoo', u'norm'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'strip', u'realign', u'norm', u'strip', u'realign', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'strip',
#   u'strip',
#   u'realign'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'stc'),
#  (u'realign', u'norm', u'realign', u'spatsmoo', u'norm'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'stc'),
#  (u'realign', u'stc', u'realign', u'spatsmoo', u'stc'),
#  (u'spatsmoo', u'norm', u'realign', u'spatsmoo', u'norm'),
#  (u'realign', u'norm', u'norm', u'realign', u'norm', u'spatsmoo', u'norm'),
#  (u'stc', u'stc', u'stc'),
#  (u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'norm',
#   u'stc',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign',),
#  (u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'spatsmoo', u'realign', u'spatsmoo', u'realign', u'spatsmoo'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'strip',
#   u'realign',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'norm',
#   u'stc'),
#  (u'norm', u'norm', u'stc', u'norm', u'norm', u'stc'),
#  (u'realign', u'spatsmoo', u'norm', u'realign', u'spatsmoo', u'norm', u'norm'),
#  (u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'realign', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'realign', u'norm', u'realign', u'norm'),
#  (u'strip', u'realign', u'realign', u'spatsmoo'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'realign', u'realign', u'spatsmoo'),
#  (u'realign',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'stc'),
#  (u'strip', u'strip', u'norm', u'strip', u'strip', u'norm'),
#  (u'realign',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc'),
#  (u'realign',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'norm',
#   u'realign',
#   u'norm',
#   u'norm'),
#  (u'realign', u'norm', u'strip', u'strip', u'realign', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'spatsmoo',
#   u'stc',
#   u'realign',
#   u'spatsmoo'),
#  (u'realign', u'norm', u'realign', u'norm', u'norm'),
#  (u'strip', u'strip', u'realign', u'norm', u'realign'),
#  (u'norm',),
#  (u'spatsmoo', u'norm', u'norm', u'realign', u'spatsmoo', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'stc'),
#  (u'spatsmoo', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'spatsmoo'),
#  (u'realign', u'spatsmoo', u'realign', u'spatsmoo'),
#  (u'realign', u'spatsmoo', u'norm', u'spatsmoo'),
#  (u'norm', u'spatsmoo', u'norm', u'spatsmoo'),
#  (u'realign', u'realign', u'spatsmoo'),
#  (u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'strip',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'norm',
#   u'strip',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'norm'),
#  (u'realign', u'realign', u'norm'),
#  (u'realign', u'spatsmoo', u'norm', u'realign', u'spatsmoo', u'norm'),
#  (u'realign',
#   u'spatsmoo',
#   u'realign',
#   u'norm',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign',
#   u'norm',
#   u'stc',
#   u'realign',
#   u'stc',
#   u'realign',
#   u'norm',
#   u'stc'),
#  (u'strip', u'strip'),
#  (u'spatsmoo', u'norm', u'norm', u'spatsmoo', u'norm', u'norm'),
#  (u'realign', u'spatsmoo', u'stc', u'realign', u'spatsmoo', u'stc'),
#  (u'realign', u'norm', u'norm', u'realign', u'spatsmoo'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm'),
#  (u'realign', u'norm', u'stc', u'realign', u'norm', u'stc'),
#  (u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc',
#   u'strip',
#   u'realign',
#   u'spatsmoo',
#   u'norm',
#   u'stc')]
